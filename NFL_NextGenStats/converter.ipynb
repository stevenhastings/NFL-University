# %%
import pandas as pd
import json

# %%
# df = pd.concat(map(pd.read_csv, [
                                #  "G:\\My Drive\\NFL_DATA\\data\\tracking_data\\week1.csv",
                                #  "G:\\My Drive\\NFL_DATA\\data\\tracking_data\\week2.csv",
                                #  "G:\\My Drive\\NFL_DATA\\data\\tracking_data\\week3.csv",
                #                  "G:\\My Drive\\NFL_DATA\\data\\tracking_data\\week4.csv",
                #                  "G:\\My Drive\\NFL_DATA\\data\\tracking_data\\week5.csv",
                #                  "G:\\My Drive\\NFL_DATA\\data\\tracking_data\\week6.csv",
                #                  "G:\\My Drive\\NFL_DATA\\data\\tracking_data\\week7.csv",
                #                  "G:\\My Drive\\NFL_DATA\\data\\tracking_data\\week8.csv"
                #                  ]
                #     )
                # )
# Above dataframe saved to df but was too large for pandas or whomever to hold in memory.
#  I do like that method though, if ever I am in a similar situation.

#############################################################################################################################################

# w1 = pd.read_csv("G:\\My Drive\\NFL_DATA\\data\\tracking_data\\week1.csv")
# w2 = pd.read_csv("G:\\My Drive\\NFL_DATA\\data\\tracking_data\\week2.csv")
# w3 = pd.read_csv("G:\\My Drive\\NFL_DATA\\data\\tracking_data\\week3.csv")
# w4 = pd.read_csv("G:\\My Drive\\NFL_DATA\\data\\tracking_data\\week4.csv")
# w5 = pd.read_csv("G:\\My Drive\\NFL_DATA\\data\\tracking_data\\week5.csv")
# w6 = pd.read_csv("G:\\My Drive\\NFL_DATA\\data\\tracking_data\\week6.csv")
# w7 = pd.read_csv("G:\\My Drive\\NFL_DATA\\data\\tracking_data\\week7.csv")
# w8 = pd.read_csv("G:\\My Drive\\NFL_DATA\\data\\tracking_data\\week8.csv")

# %%
games = pd.read_csv("G:\\My Drive\\NFL_DATA\\data\\games.csv")
# plays = pd.read_csv("G:\My Drive\NFL_DATA\data\plays.csv")
# players = pd.read_csv("G:\My Drive\NFL_DATA\data\players.csv")
# scouting = pd.read_csv("G:\My Drive\NFL_DATA\data\pffScoutingData.csv")
games.shape
# Out:
# (122, 7)

# %%
result = games.to_json(orient="table")
parsed = json.loads(result)
# json.dumps(parsed, indent=1)
parsed
# Out:
# {'schema': {'fields': [{'name': 'index', 'type': 'integer'},
#    {'name': 'gameId', 'type': 'integer'},
#    {'name': 'season', 'type': 'integer'},
#    {'name': 'week', 'type': 'integer'},
#    {'name': 'gameDate', 'type': 'string'},
#    {'name': 'gameTimeEastern', 'type': 'string'},
#    {'name': 'homeTeamAbbr', 'type': 'string'},
#    {'name': 'visitorTeamAbbr', 'type': 'string'}],
#   'primaryKey': ['index'],
#   'pandas_version': '1.4.0'},
#  'data': [{'index': 0,
#    'gameId': 2021090900,
#    'season': 2021,
#    'week': 1,
#    'gameDate': '09/09/2021',
#    'gameTimeEastern': '20:20:00',
#    'homeTeamAbbr': 'TB',
#    'visitorTeamAbbr': 'DAL'},
#   {'index': 1,
#    'gameId': 2021091200,
#    'season': 2021,
#    'week': 1,
#    'gameDate': '09/12/2021',
#    'gameTimeEastern': '13:00:00',
#    'homeTeamAbbr': 'ATL',
#    'visitorTeamAbbr': 'PHI'},
#   {'index': 2,
#    'gameId': 2021091201,
#    'season': 2021,
#    'week': 1,
#    'gameDate': '09/12/2021',
# ...

# %%
# Out:
# '{"schema":{"fields":[{"name":"index","type":"integer"},{"name":"gameId","type":"integer"},{"name":"season","type":"integer"},{"name":"week","type":"integer"},{"name":"gameDate","type":"string"},{"name":"gameTimeEastern","type":"string"},{"name":"homeTeamAbbr","type":"string"},{"name":"visitorTeamAbbr","type":"string"}],"primaryKey":["index"],"pandas_version":"1.4.0"},"data":[{"index":0,"gameId":2021090900,"season":2021,"week":1,"gameDate":"09\\/09\\/2021","gameTimeEastern":"20:20:00","homeTeamAbbr":"TB","visitorTeamAbbr":"DAL"},{"index":1,"gameId":2021091200,"season":2021,"week":1,"gameDate":"09\\/12\\/2021","gameTimeEastern":"13:00:00","homeTeamAbbr":"ATL","visitorTeamAbbr":"PHI"},{"index":2,"gameId":2021091201,"season":2021,"week":1,"gameDate":"09\\/12\\/2021","gameTimeEastern":"13:00:00","homeTeamAbbr":"BUF","visitorTeamAbbr":"PIT"},{"index":3,"gameId":2021091202,"season":2021,"week":1,"gameDate":"09\\/12\\/2021","gameTimeEastern":"13:00:00","homeTeamAbbr":"CAR","visitorTeamAbbr"
# ...

# %%
schema = pd.io.json.build_table_schema(games, index=True, primary_key=None, version=True)

schema
# Out:
# {'fields': [{'name': 'index', 'type': 'integer'},
#   {'name': 'gameId', 'type': 'integer'},
#   {'name': 'season', 'type': 'integer'},
#   {'name': 'week', 'type': 'integer'},
#   {'name': 'gameDate', 'type': 'string'},
#   {'name': 'gameTimeEastern', 'type': 'string'},
#   {'name': 'homeTeamAbbr', 'type': 'string'},
#   {'name': 'visitorTeamAbbr', 'type': 'string'}],
#  'primaryKey': ['index'],
#  'pandas_version': '1.4.0'}
